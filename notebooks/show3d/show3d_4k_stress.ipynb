# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
from quantem.widget import IO, Show3D
import numpy as np

# %%
result = IO.folder("/Users/macbook/data/bob/20260409_gold_drift_v3", file_type="emd", shape=(4096, 4096))
result.describe()
# Out:
# files:   0%|          | 0/14 [00:00<?, ?it/s]
# Filtered: kept 12/14 files matching shape=(4096, 4096)
# IO.folder: 12×4096×4096 768 MB (12 files) in 282 ms (24 ms/file)  pixel_size=0.1861 Å
#   Image:          12 × 4096 × 4096
#   Pixel size:     0.1861 Å (0.0186 nm)
#   Field of view:  76.2 nm
#   Instrument:     Spectra / Titan / XFEG
#   Voltage:          300 kV
#   Convergence:      30.0 mrad
#   Camera length:    91 mm
#   Spot size:        6
#   Screen current:   0.14 nA
#   Dwell time:     2.0 µs  (frame: 38.3 s)
#   Scan size:      4096 × 4096
#   Detector:       HAADF (63–200 mrad)
#   Sample:         gold_3.6mx_drift
#   Stage:          x=39.0, y=21.3, z=-199 µm

# %% [markdown]
# ## Single panel (12×4K, auto-bin 2×)

# %%
w = Show3D(result.data, pixel_size=result.pixel_size)
w
# Out:
#   Display bin 2×: 4096×4096 → 2048×2048 (16 MB/frame)
# Show3D(12×2048×2048, frame=6, cmap=magma)

# %% [markdown]
# ## 3-panel comparison (Raw vs Log vs Sqrt, auto-bin 4×)

# %%
d_log = np.log1p(np.maximum(result.data, 0))
d_sqrt = result.data ** 0.5
w3 = Show3D(result.data, d_log, d_sqrt, panel_titles=["Raw HAADF", "Log", "Sqrt"])
w3
# Out:
#   Display bin 4× (multi-panel): 1024×3076 (12 MB/frame)
# Show3D(12×1024×3076, frame=6, cmap=magma)
