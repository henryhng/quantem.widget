# %% [markdown]
# # Show4DSTEM Batch CLI + Adaptive Export Demo
# Run the non-interactive CLI for single/frame/adaptive exports and inspect JSONL/manifest outputs.

# %%
try:
    # %load_ext autoreload
    # %autoreload 2
    # %env ANYWIDGET_HMR=1
except Exception:
    pass
# Out:
# env: ANYWIDGET_HMR=1

# %%
import json
import math
import pathlib
import numpy as np
import torch
import quantem.widget
from quantem.widget import Show4DSTEM, profile
def make_crystal_4dstem(
    scan_shape=(40, 40),
    det_shape=(72, 72),
    n_frames=1,
    seed=7,
    device=None,
):
    if device is None:
        device = torch.device(
            "mps"
            if torch.backends.mps.is_available()
            else "cuda"
            if torch.cuda.is_available()
            else "cpu"
        )
    torch.manual_seed(seed)
    sy, sx = scan_shape
    ky, kx = det_shape
    fy = 1.0 if n_frames == 1 else float(n_frames)
    y = torch.linspace(-1.0, 1.0, sy, device=device)
    x = torch.linspace(-1.0, 1.0, sx, device=device)
    Y, X = torch.meshgrid(y, x, indexing="ij")
    frame_axis = torch.linspace(0.0, 1.0, n_frames, device=device)
    phase_t = 2.0 * math.pi * frame_axis[:, None, None]
    # Synthetic strain/defect field with crystal-like periodicity.
    lattice = 0.35 * torch.sin(2.0 * math.pi * (7.0 * X + 0.35 * Y))
    lattice += 0.30 * torch.sin(2.0 * math.pi * (7.0 * Y - 0.25 * X))
    defect = 0.55 * torch.exp(-((X + 0.20) ** 2 + (Y - 0.25) ** 2) / 0.05)
    defect += 0.35 * torch.exp(-((X - 0.35) ** 2 + (Y + 0.10) ** 2) / 0.03)
    structural = lattice + defect
    structural_t = structural[None, :, :] + 0.08 * torch.sin(phase_t + 5.0 * X[None, :, :])
    ky_axis = torch.linspace(0.0, float(ky - 1), ky, device=device)
    kx_axis = torch.linspace(0.0, float(kx - 1), kx, device=device)
    KY, KX = torch.meshgrid(ky_axis, kx_axis, indexing="ij")
    KY = KY[None, None, None, :, :]
    KX = KX[None, None, None, :, :]
    cy = (ky - 1) / 2.0
    cx = (kx - 1) / 2.0
    # Shift Bragg spots according to local strain/field.
    shift_y = 1.4 * structural_t[:, :, :, None, None]
    shift_x = -1.1 * structural_t[:, :, :, None, None]
    frame_mod = 1.0 + 0.20 * torch.sin(phase_t)[:, :, :, None, None]
    dp = torch.zeros((n_frames, sy, sx, ky, kx), device=device)
    sigma_direct = 2.8
    direct_amp = 180.0 * frame_mod
    dp += direct_amp * torch.exp(-((KY - cy) ** 2 + (KX - cx) ** 2) / (2.0 * sigma_direct**2))
    spot_sigma = 2.1
    base_spots = [
        (-16.0, 0.0, 75.0),
        (16.0, 0.0, 75.0),
        (0.0, -16.0, 72.0),
        (0.0, 16.0, 72.0),
        (-11.0, -11.0, 58.0),
        (11.0, 11.0, 58.0),
        (-11.0, 11.0, 54.0),
        (11.0, -11.0, 54.0),
    ]
    amp_field = 1.0 + 0.45 * torch.relu(structural_t)[:, :, :, None, None]
    for dy, dx, amp in base_spots:
        cy_t = cy + dy + shift_y
        cx_t = cx + dx + shift_x
        dp += (amp * amp_field) * torch.exp(
            -((KY - cy_t) ** 2 + (KX - cx_t) ** 2) / (2.0 * spot_sigma**2)
        )
    ring_r = torch.sqrt((KY - cy) ** 2 + (KX - cx) ** 2)
    dp += 12.0 * torch.exp(-((ring_r - 23.0) ** 2) / (2.0 * 7.0**2))
    if device.type == "mps":
        # MPS currently lacks aten::poisson; sample on CPU then move back.
        shot = torch.poisson(torch.clamp(dp.cpu(), min=0.0)).to(device)
    else:
        shot = torch.poisson(torch.clamp(dp, min=0.0))
    dp = shot + 0.6 * torch.randn_like(shot)
    dp = torch.clamp(dp, min=0.0).to(torch.float32)
    arr = dp.cpu().numpy()
    if n_frames == 1:
        return arr[0]
    return arr
DEVICE = torch.device(
    "mps"
    if torch.backends.mps.is_available()
    else "cuda"
    if torch.cuda.is_available()
    else "cpu"
)
print(f"Using device: {DEVICE}")
import subprocess
import sys
print(f"quantem.widget {quantem.widget.__version__}")
profile()

# %%
OUT = pathlib.Path('notebooks/show4dstem/paper_cli')
OUT.mkdir(parents=True, exist_ok=True)
input_path = OUT / 'synthetic_4dstem.npy'
data = make_crystal_4dstem(scan_shape=(36, 36), det_shape=(72, 72), n_frames=3, seed=33, device=DEVICE)
np.save(input_path, data)
preview = Show4DSTEM(data, pixel_size=0.80, k_pixel_size=0.53)
preview.auto_detect_center()
preview.roi_circle()
preview.roi_radius = 12
preview
# Out:
# Show4DSTEM(shape=(3, 36, 36, 72, 72), sampling=(0.8 Å, 0.53 mrad), pos=(18, 18), frame=0)

# %%
batch_dir = OUT / 'batch_outputs'
cmd = [
    sys.executable,
    '-m',
    'quantem.widget.show4dstem_batch',
    '--input', str(input_path),
    '--output-dir', str(batch_dir),
    '--mode', 'adaptive',
    '--adaptive-target-fraction', '0.30',
    '--adaptive-coarse-step', '4',
    '--adaptive-min-spacing', '2',
    '--view', 'all',
    '--format', 'png',
    '--manifest-name', 'adaptive_manifest.json',
    '--batch-manifest', 'batch_manifest.jsonl',
    '--report-name', 'adaptive_report.json',
]
res = subprocess.run(cmd, check=True, capture_output=True, text=True)
print(res.stdout)
# Out:
# [1/1] ok    synthetic_4dstem.npy t=7.21s mode=adaptive view=all
# Processed: ok=1, error=0, total=1, elapsed=7.21s, manifest=notebooks/show4dstem/paper_cli/batch_outputs/batch_manifest.jsonl

# %%
manifest_rows = [json.loads(line) for line in (batch_dir / 'batch_manifest.jsonl').read_text().splitlines() if line.strip()]
manifest_rows
# Out:
# [{'index': 1,
#   'total': 1,
#   'status': 'ok',
#   'input': 'notebooks/show4dstem/paper_cli/synthetic_4dstem.npy',
#   'output_dir': 'notebooks/show4dstem/paper_cli/batch_outputs',
#   'mode': 'adaptive',
#   'view': 'all',
#   'format': 'png',
#   'elapsed_sec': 7.211370499993791,
#   'sequence_manifest_path': 'notebooks/show4dstem/paper_cli/batch_outputs/adaptive_manifest.json',
#   'report_path': 'notebooks/show4dstem/paper_cli/batch_outputs/adaptive_report.json',
#   'adaptive': {'target_count': 389,
#    'coarse_count': 81,
#    'dense_count': 179,
#    'path_count': 260,
#    'selected_fraction': 0.2006172839506173}}]

# %%
sequence_manifest = json.loads((batch_dir / 'adaptive_manifest.json').read_text())
report = json.loads((batch_dir / 'adaptive_report.json').read_text())
summary = {
    'metadata_version': sequence_manifest['metadata_version'],
    'widget_version': sequence_manifest['widget_version'],
    'n_exports': sequence_manifest['n_exports'],
    'include_overlays': sequence_manifest['include_overlays'],
    'include_scalebar': sequence_manifest['include_scalebar'],
    'report_n_exports': report['n_exports'],
}
summary
# Out:
# {'metadata_version': '1.0',
#  'widget_version': '0.4.0a2',
#  'n_exports': 260,
#  'include_overlays': True,
#  'include_scalebar': True,
#  'report_n_exports': 262}

# %%
sorted(str(p.relative_to(OUT)) for p in OUT.rglob('*') if p.is_file())
# Out:
# ['batch_outputs/adaptive_manifest.json',
#  'batch_outputs/adaptive_report.json',
#  'batch_outputs/batch_manifest.jsonl',
#  'batch_outputs/path_all_0000_f0000_r0000_c0000.json',
#  'batch_outputs/path_all_0000_f0000_r0000_c0000.png',
#  'batch_outputs/path_all_0001_f0000_r0000_c0004.json',
#  'batch_outputs/path_all_0001_f0000_r0000_c0004.png',
#  'batch_outputs/path_all_0002_f0000_r0000_c0008.json',
#  'batch_outputs/path_all_0002_f0000_r0000_c0008.png',
#  'batch_outputs/path_all_0003_f0000_r0000_c0012.json',
#  'batch_outputs/path_all_0003_f0000_r0000_c0012.png',
#  'batch_outputs/path_all_0004_f0000_r0000_c0016.json',
#  'batch_outputs/path_all_0004_f0000_r0000_c0016.png',
#  'batch_outputs/path_all_0005_f0000_r0000_c0020.json',
#  'batch_outputs/path_all_0005_f0000_r0000_c0020.png',
#  'batch_outputs/path_all_0006_f0000_r0000_c0024.json',
#  'batch_outputs/path_all_0006_f0000_r0000_c0024.png',
#  'batch_outputs/path_all_0007_f0000_r0000_c0028.json',
#  'batch_outputs/path_all_0007_f0000_r0000_c0028.png',
#  'batch_outputs/path_all_0008_f0000_r0000_c0032.json',
#  'batch_outputs/path_all_0008_f0000_r0000_c0032.png',
#  'batch_outputs/path_all_0009_f0000_r0004_c0032.json',
#  'batch_outputs/path_all_0009_f0000_r0004_c0032.png',
#  'batch_outputs/path_all_0010_f0000_r0004_c0028.json',
#  'batch_outputs/path_all_0010_f0000_r0004_c0028.png',
#  'batch_outputs/path_all_0011_f0000_r0004_c0024.json',
#  'batch_outputs/path_all_0011_f0000_r0004_c0024.png',
#  'batch_outputs/path_all_0012_f0000_r0004_c0020.json',
#  'batch_outputs/path_all_0012_f0000_r0004_c0020.png',
#  'batch_outputs/path_all_0013_f0000_r0004_c0016.json',
#  'batch_outputs/path_all_0013_f0000_r0004_c0016.png',
#  'batch_outputs/path_all_0014_f0000_r0004_c0012.json',
#  'batch_outputs/path_all_0014_f0000_r0004_c0012.png',
#  'batch_outputs/path_all_0015_f0000_r0004_c0008.json',
#  'batch_outputs/path_all_0015_f0000_r0004_c0008.png',
#  'batch_outputs/path_all_0016_f0000_r0004_c0004.json',
#  'batch_outputs/path_all_0016_f0000_r0004_c0004.png',
#  'batch_outputs/path_all_0017_f0000_r0004_c0000.json',
#  'batch_outputs/path_all_0017_f0000_r0004_c0000.png',
#  'batch_outputs/path_all_0018_f0000_r0008_c0000.json',
#  'batch_outputs/path_all_0018_f0000_r0008_c0000.png',
#  'batch_outputs/path_all_0019_f0000_r0008_c0004.json',
#  'batch_outputs/path_all_0019_f0000_r0008_c0004.png',
#  'batch_outputs/path_all_0020_f0000_r0008_c0008.json',
#  'batch_outputs/path_all_0020_f0000_r0008_c0008.png',
#  'batch_outputs/path_all_0021_f0000_r0008_c0012.json',
#  'batch_outputs/path_all_0021_f0000_r0008_c0012.png',
#  'batch_outputs/path_all_0022_f0000_r0008_c0016.json',
#  'batch_outputs/path_all_0022_f0000_r0008_c0016.png',
#  'batch_outputs/path_all_0023_f0000_r0008_c0020.json',
#  'batch_outputs/path_all_0023_f0000_r0008_c0020.png',
#  'batch_outputs/path_all_0024_f0000_r0008_c0024.json',
#  'batch_outputs/path_all_0024_f0000_r0008_c0024.png',
#  'batch_outputs/path_all_0025_f0000_r0008_c0028.json',
#  'batch_outputs/path_all_0025_f0000_r0008_c0028.png',
#  'batch_outputs/path_all_0026_f0000_r0008_c0032.json',
#  'batch_outputs/path_all_0026_f0000_r0008_c0032.png',
#  'batch_outputs/path_all_0027_f0000_r0012_c0032.json',
#  'batch_outputs/path_all_0027_f0000_r0012_c0032.png',
#  'batch_outputs/path_all_0028_f0000_r0012_c0028.json',
#  'batch_outputs/path_all_0028_f0000_r0012_c0028.png',
#  'batch_outputs/path_all_0029_f0000_r0012_c0024.json',
#  'batch_outputs/path_all_0029_f0000_r0012_c0024.png',
#  'batch_outputs/path_all_0030_f0000_r0012_c0020.json',
#  'batch_outputs/path_all_0030_f0000_r0012_c0020.png',
#  'batch_outputs/path_all_0031_f0000_r0012_c0016.json',
#  'batch_outputs/path_all_0031_f0000_r0012_c0016.png',
#  'batch_outputs/path_all_0032_f0000_r0012_c0012.json',
#  'batch_outputs/path_all_0032_f0000_r0012_c0012.png',
#  'batch_outputs/path_all_0033_f0000_r0012_c0008.json',
#  'batch_outputs/path_all_0033_f0000_r0012_c0008.png',
#  'batch_outputs/path_all_0034_f0000_r0012_c0004.json',
#  'batch_outputs/path_all_0034_f0000_r0012_c0004.png',
#  'batch_outputs/path_all_0035_f0000_r0012_c0000.json',
#  'batch_outputs/path_all_0035_f0000_r0012_c0000.png',
#  'batch_outputs/path_all_0036_f0000_r0016_c0000.json',
#  'batch_outputs/path_all_0036_f0000_r0016_c0000.png',
#  'batch_outputs/path_all_0037_f0000_r0016_c0004.json',
#  'batch_outputs/path_all_0037_f0000_r0016_c0004.png',
#  'batch_outputs/path_all_0038_f0000_r0016_c0008.json',
#  'batch_outputs/path_all_0038_f0000_r0016_c0008.png',
#  'batch_outputs/path_all_0039_f0000_r0016_c0012.json',
#  'batch_outputs/path_all_0039_f0000_r0016_c0012.png',
#  'batch_outputs/path_all_0040_f0000_r0016_c0016.json',
#  'batch_outputs/path_all_0040_f0000_r0016_c0016.png',
#  'batch_outputs/path_all_0041_f0000_r0016_c0020.json',
#  'batch_outputs/path_all_0041_f0000_r0016_c0020.png',
#  'batch_outputs/path_all_0042_f0000_r0016_c0024.json',
#  'batch_outputs/path_all_0042_f0000_r0016_c0024.png',
#  'batch_outputs/path_all_0043_f0000_r0016_c0028.json',
#  'batch_outputs/path_all_0043_f0000_r0016_c0028.png',
#  'batch_outputs/path_all_0044_f0000_r0016_c0032.json',
#  'batch_outputs/path_all_0044_f0000_r0016_c0032.png',
#  'batch_outputs/path_all_0045_f0000_r0020_c0032.json',
#  'batch_outputs/path_all_0045_f0000_r0020_c0032.png',
#  'batch_outputs/path_all_0046_f0000_r0020_c0028.json',
#  'batch_outputs/path_all_0046_f0000_r0020_c0028.png',
#  'batch_outputs/path_all_0047_f0000_r0020_c0024.json',
#  'batch_outputs/path_all_0047_f0000_r0020_c0024.png',
#  'batch_outputs/path_all_0048_f0000_r0020_c0020.json',
#  'batch_outputs/path_all_0048_f0000_r0020_c0020.png',
#  'batch_outputs/path_all_0049_f0000_r0020_c0016.json',
#  'batch_outputs/path_all_0049_f0000_r0020_c0016.png',
#  'batch_outputs/path_all_0050_f0000_r0020_c0012.json',
#  'batch_outputs/path_all_0050_f0000_r0020_c0012.png',
#  'batch_outputs/path_all_0051_f0000_r0020_c0008.json',
#  'batch_outputs/path_all_0051_f0000_r0020_c0008.png',
#  'batch_outputs/path_all_0052_f0000_r0020_c0004.json',
#  'batch_outputs/path_all_0052_f0000_r0020_c0004.png',
#  'batch_outputs/path_all_0053_f0000_r0020_c0000.json',
#  'batch_outputs/path_all_0053_f0000_r0020_c0000.png',
#  'batch_outputs/path_all_0054_f0000_r0024_c0000.json',
#  'batch_outputs/path_all_0054_f0000_r0024_c0000.png',
#  'batch_outputs/path_all_0055_f0000_r0024_c0004.json',
#  'batch_outputs/path_all_0055_f0000_r0024_c0004.png',
#  'batch_outputs/path_all_0056_f0000_r0024_c0008.json',
#  'batch_outputs/path_all_0056_f0000_r0024_c0008.png',
#  'batch_outputs/path_all_0057_f0000_r0024_c0012.json',
#  'batch_outputs/path_all_0057_f0000_r0024_c0012.png',
#  'batch_outputs/path_all_0058_f0000_r0024_c0016.json',
#  'batch_outputs/path_all_0058_f0000_r0024_c0016.png',
#  'batch_outputs/path_all_0059_f0000_r0024_c0020.json',
#  'batch_outputs/path_all_0059_f0000_r0024_c0020.png',
#  'batch_outputs/path_all_0060_f0000_r0024_c0024.json',
#  'batch_outputs/path_all_0060_f0000_r0024_c0024.png',
#  'batch_outputs/path_all_0061_f0000_r0024_c0028.json',
#  'batch_outputs/path_all_0061_f0000_r0024_c0028.png',
#  'batch_outputs/path_all_0062_f0000_r0024_c0032.json',
#  'batch_outputs/path_all_0062_f0000_r0024_c0032.png',
#  'batch_outputs/path_all_0063_f0000_r0028_c0032.json',
#  'batch_outputs/path_all_0063_f0000_r0028_c0032.png',
#  'batch_outputs/path_all_0064_f0000_r0028_c0028.json',
#  'batch_outputs/path_all_0064_f0000_r0028_c0028.png',
#  'batch_outputs/path_all_0065_f0000_r0028_c0024.json',
#  'batch_outputs/path_all_0065_f0000_r0028_c0024.png',
#  'batch_outputs/path_all_0066_f0000_r0028_c0020.json',
#  'batch_outputs/path_all_0066_f0000_r0028_c0020.png',
#  'batch_outputs/path_all_0067_f0000_r0028_c0016.json',
#  'batch_outputs/path_all_0067_f0000_r0028_c0016.png',
#  'batch_outputs/path_all_0068_f0000_r0028_c0012.json',
#  'batch_outputs/path_all_0068_f0000_r0028_c0012.png',
#  'batch_outputs/path_all_0069_f0000_r0028_c0008.json',
#  'batch_outputs/path_all_0069_f0000_r0028_c0008.png',
#  'batch_outputs/path_all_0070_f0000_r0028_c0004.json',
#  'batch_outputs/path_all_0070_f0000_r0028_c0004.png',
#  'batch_outputs/path_all_0071_f0000_r0028_c0000.json',
#  'batch_outputs/path_all_0071_f0000_r0028_c0000.png',
#  'batch_outputs/path_all_0072_f0000_r0032_c0000.json',
#  'batch_outputs/path_all_0072_f0000_r0032_c0000.png',
#  'batch_outputs/path_all_0073_f0000_r0032_c0004.json',
#  'batch_outputs/path_all_0073_f0000_r0032_c0004.png',
#  'batch_outputs/path_all_0074_f0000_r0032_c0008.json',
#  'batch_outputs/path_all_0074_f0000_r0032_c0008.png',
#  'batch_outputs/path_all_0075_f0000_r0032_c0012.json',
#  'batch_outputs/path_all_0075_f0000_r0032_c0012.png',
#  'batch_outputs/path_all_0076_f0000_r0032_c0016.json',
#  'batch_outputs/path_all_0076_f0000_r0032_c0016.png',
#  'batch_outputs/path_all_0077_f0000_r0032_c0020.json',
#  'batch_outputs/path_all_0077_f0000_r0032_c0020.png',
#  'batch_outputs/path_all_0078_f0000_r0032_c0024.json',
#  'batch_outputs/path_all_0078_f0000_r0032_c0024.png',
#  'batch_outputs/path_all_0079_f0000_r0032_c0028.json',
#  'batch_outputs/path_all_0079_f0000_r0032_c0028.png',
#  'batch_outputs/path_all_0080_f0000_r0032_c0032.json',
#  'batch_outputs/path_all_0080_f0000_r0032_c0032.png',
#  'batch_outputs/path_all_0081_f0000_r0031_c0032.json',
#  'batch_outputs/path_all_0081_f0000_r0031_c0032.png',
#  'batch_outputs/path_all_0082_f0000_r0029_c0033.json',
#  'batch_outputs/path_all_0082_f0000_r0029_c0033.png',
#  'batch_outputs/path_all_0083_f0000_r0031_c0035.json',
#  'batch_outputs/path_all_0083_f0000_r0031_c0035.png',
#  'batch_outputs/path_all_0084_f0000_r0033_c0034.json',
#  'batch_outputs/path_all_0084_f0000_r0033_c0034.png',
#  'batch_outputs/path_all_0085_f0000_r0035_c0035.json',
#  'batch_outputs/path_all_0085_f0000_r0035_c0035.png',
#  'batch_outputs/path_all_0086_f0000_r0035_c0032.json',
#  'batch_outputs/path_all_0086_f0000_r0035_c0032.png',
#  'batch_outputs/path_all_0087_f0000_r0034_c0030.json',
#  'batch_outputs/path_all_0087_f0000_r0034_c0030.png',
#  'batch_outputs/path_all_0088_f0000_r0032_c0029.json',
#  'batch_outputs/path_all_0088_f0000_r0032_c0029.png',
#  'batch_outputs/path_all_0089_f0000_r0031_c0027.json',
#  'batch_outputs/path_all_0089_f0000_r0031_c0027.png',
#  'batch_outputs/path_all_0090_f0000_r0030_c0025.json',
#  'batch_outputs/path_all_0090_f0000_r0030_c0025.png',
#  'batch_outputs/path_all_0091_f0000_r0028_c0023.json',
#  'batch_outputs/path_all_0091_f0000_r0028_c0023.png',
#  'batch_outputs/path_all_0092_f0000_r0026_c0025.json',
#  'batch_outputs/path_all_0092_f0000_r0026_c0025.png',
#  'batch_outputs/path_all_0093_f0000_r0024_c0026.json',
#  'batch_outputs/path_all_0093_f0000_r0024_c0026.png',
#  'batch_outputs/path_all_0094_f0000_r0023_c0028.json',
#  'batch_outputs/path_all_0094_f0000_r0023_c0028.png',
#  'batch_outputs/path_all_0095_f0000_r0024_c0030.json',
#  'batch_outputs/path_all_0095_f0000_r0024_c0030.png',
#  'batch_outputs/path_all_0096_f0000_r0023_c0032.json',
#  'batch_outputs/path_all_0096_f0000_r0023_c0032.png',
#  'batch_outputs/path_all_0097_f0000_r0021_c0033.json',
#  'batch_outputs/path_all_0097_f0000_r0021_c0033.png',
#  'batch_outputs/path_all_0098_f0000_r0019_c0035.json',
#  'batch_outputs/path_all_0098_f0000_r0019_c0035.png',
#  'batch_outputs/path_all_0099_f0000_r0017_c0033.json',
#  'batch_outputs/path_all_0099_f0000_r0017_c0033.png',
#  'batch_outputs/path_all_0100_f0000_r0016_c0031.json',
#  'batch_outputs/path_all_0100_f0000_r0016_c0031.png',
#  'batch_outputs/path_all_0101_f0000_r0015_c0029.json',
#  'batch_outputs/path_all_0101_f0000_r0015_c0029.png',
#  'batch_outputs/path_all_0102_f0000_r0013_c0031.json',
#  'batch_outputs/path_all_0102_f0000_r0013_c0031.png',
#  'batch_outputs/path_all_0103_f0000_r0014_c0033.json',
#  'batch_outputs/path_all_0103_f0000_r0014_c0033.png',
#  'batch_outputs/path_all_0104_f0000_r0015_c0035.json',
#  'batch_outputs/path_all_0104_f0000_r0015_c0035.png',
#  'batch_outputs/path_all_0105_f0000_r0011_c0035.json',
#  'batch_outputs/path_all_0105_f0000_r0011_c0035.png',
#  'batch_outputs/path_all_0106_f0000_r0011_c0032.json',
#  'batch_outputs/path_all_0106_f0000_r0011_c0032.png',
#  'batch_outputs/path_all_0107_f0000_r0009_c0031.json',
#  'batch_outputs/path_all_0107_f0000_r0009_c0031.png',
#  'batch_outputs/path_all_0108_f0000_r0007_c0030.json',
#  'batch_outputs/path_all_0108_f0000_r0007_c0030.png',
#  'batch_outputs/path_all_0109_f0000_r0005_c0031.json',
#  'batch_outputs/path_all_0109_f0000_r0005_c0031.png',
#  'batch_outputs/path_all_0110_f0000_r0006_c0033.json',
#  'batch_outputs/path_all_0110_f0000_r0006_c0033.png',
#  'batch_outputs/path_all_0111_f0000_r0008_c0035.json',
#  'batch_outputs/path_all_0111_f0000_r0008_c0035.png',
#  'batch_outputs/path_all_0112_f0000_r0003_c0035.json',
#  'batch_outputs/path_all_0112_f0000_r0003_c0035.png',
#  'batch_outputs/path_all_0113_f0000_r0001_c0034.json',
#  'batch_outputs/path_all_0113_f0000_r0001_c0034.png',
#  'batch_outputs/path_all_0114_f0000_r0003_c0032.json',
#  'batch_outputs/path_all_0114_f0000_r0003_c0032.png',
#  'batch_outputs/path_all_0115_f0000_r0001_c0031.json',
#  'batch_outputs/path_all_0115_f0000_r0001_c0031.png',
#  'batch_outputs/path_all_0116_f0000_r0000_c0029.json',
#  'batch_outputs/path_all_0116_f0000_r0000_c0029.png',
#  'batch_outputs/path_all_0117_f0000_r0001_c0027.json',
#  'batch_outputs/path_all_0117_f0000_r0001_c0027.png',
#  'batch_outputs/path_all_0118_f0000_r0001_c0024.json',
#  'batch_outputs/path_all_0118_f0000_r0001_c0024.png',
#  'batch_outputs/path_all_0119_f0000_r0003_c0023.json',
#  'batch_outputs/path_all_0119_f0000_r0003_c0023.png',
#  'batch_outputs/path_all_0120_f0000_r0001_c0021.json',
#  'batch_outputs/path_all_0120_f0000_r0001_c0021.png',
#  'batch_outputs/path_all_0121_f0000_r0000_c0019.json',
#  'batch_outputs/path_all_0121_f0000_r0000_c0019.png',
#  'batch_outputs/path_all_0122_f0000_r0001_c0017.json',
#  'batch_outputs/path_all_0122_f0000_r0001_c0017.png',
#  'batch_outputs/path_all_0123_f0000_r0003_c0019.json',
#  'batch_outputs/path_all_0123_f0000_r0003_c0019.png',
#  'batch_outputs/path_all_0124_f0000_r0005_c0017.json',
#  'batch_outputs/path_all_0124_f0000_r0005_c0017.png',
#  'batch_outputs/path_all_0125_f0000_r0006_c0015.json',
#  'batch_outputs/path_all_0125_f0000_r0006_c0015.png',
#  'batch_outputs/path_all_0126_f0000_r0008_c0013.json',
#  'batch_outputs/path_all_0126_f0000_r0008_c0013.png',
#  'batch_outputs/path_all_0127_f0000_r0010_c0011.json',
#  'batch_outputs/path_all_0127_f0000_r0010_c0011.png',
#  'batch_outputs/path_all_0128_f0000_r0008_c0009.json',
#  'batch_outputs/path_all_0128_f0000_r0008_c0009.png',
#  'batch_outputs/path_all_0129_f0000_r0010_c0008.json',
#  'batch_outputs/path_all_0129_f0000_r0010_c0008.png',
#  'batch_outputs/path_all_0130_f0000_r0012_c0009.json',
#  'batch_outputs/path_all_0130_f0000_r0012_c0009.png',
#  'batch_outputs/path_all_0131_f0000_r0013_c0011.json',
#  'batch_outputs/path_all_0131_f0000_r0013_c0011.png',
#  'batch_outputs/path_all_0132_f0000_r0014_c0013.json',
#  'batch_outputs/path_all_0132_f0000_r0014_c0013.png',
#  'batch_outputs/path_all_0133_f0000_r0016_c0011.json',
#  'batch_outputs/path_all_0133_f0000_r0016_c0011.png',
#  'batch_outputs/path_all_0134_f0000_r0018_c0013.json',
#  'batch_outputs/path_all_0134_f0000_r0018_c0013.png',
#  'batch_outputs/path_all_0135_f0000_r0016_c0015.json',
#  'batch_outputs/path_all_0135_f0000_r0016_c0015.png',
#  'batch_outputs/path_all_0136_f0000_r0018_c0016.json',
#  'batch_outputs/path_all_0136_f0000_r0018_c0016.png',
#  'batch_outputs/path_all_0137_f0000_r0016_c0018.json',
#  'batch_outputs/path_all_0137_f0000_r0016_c0018.png',
#  'batch_outputs/path_all_0138_f0000_r0014_c0019.json',
#  'batch_outputs/path_all_0138_f0000_r0014_c0019.png',
#  'batch_outputs/path_all_0139_f0000_r0013_c0021.json',
#  'batch_outputs/path_all_0139_f0000_r0013_c0021.png',
#  'batch_outputs/path_all_0140_f0000_r0015_c0023.json',
#  'batch_outputs/path_all_0140_f0000_r0015_c0023.png',
#  'batch_outputs/path_all_0141_f0000_r0016_c0021.json',
#  'batch_outputs/path_all_0141_f0000_r0016_c0021.png',
#  'batch_outputs/path_all_0142_f0000_r0018_c0023.json',
#  'batch_outputs/path_all_0142_f0000_r0018_c0023.png',
#  'batch_outputs/path_all_0143_f0000_r0019_c0020.json',
#  'batch_outputs/path_all_0143_f0000_r0019_c0020.png',
#  'batch_outputs/path_all_0144_f0000_r0021_c0021.json',
#  'batch_outputs/path_all_0144_f0000_r0021_c0021.png',
#  'batch_outputs/path_all_0145_f0000_r0023_c0023.json',
#  'batch_outputs/path_all_0145_f0000_r0023_c0023.png',
#  'batch_outputs/path_all_0146_f0000_r0024_c0021.json',
#  'batch_outputs/path_all_0146_f0000_r0024_c0021.png',
#  'batch_outputs/path_all_0147_f0000_r0026_c0020.json',
#  'batch_outputs/path_all_0147_f0000_r0026_c0020.png',
#  'batch_outputs/path_all_0148_f0000_r0025_c0017.json',
#  'batch_outputs/path_all_0148_f0000_r0025_c0017.png',
#  'batch_outputs/path_all_0149_f0000_r0023_c0018.json',
#  'batch_outputs/path_all_0149_f0000_r0023_c0018.png',
#  'batch_outputs/path_all_0150_f0000_r0020_c0018.json',
#  'batch_outputs/path_all_0150_f0000_r0020_c0018.png',
#  'batch_outputs/path_all_0151_f0000_r0021_c0015.json',
#  'batch_outputs/path_all_0151_f0000_r0021_c0015.png',
#  'batch_outputs/path_all_0152_f0000_r0023_c0013.json',
#  'batch_outputs/path_all_0152_f0000_r0023_c0013.png',
#  'batch_outputs/path_all_0153_f0000_r0021_c0011.json',
#  'batch_outputs/path_all_0153_f0000_r0021_c0011.png',
#  'batch_outputs/path_all_0154_f0000_r0023_c0010.json',
#  'batch_outputs/path_all_0154_f0000_r0023_c0010.png',
#  'batch_outputs/path_all_0155_f0000_r0021_c0008.json',
#  'batch_outputs/path_all_0155_f0000_r0021_c0008.png',
#  'batch_outputs/path_all_0156_f0000_r0019_c0010.json',
#  'batch_outputs/path_all_0156_f0000_r0019_c0010.png',
#  'batch_outputs/path_all_0157_f0000_r0018_c0008.json',
#  'batch_outputs/path_all_0157_f0000_r0018_c0008.png',
#  'batch_outputs/path_all_0158_f0000_r0017_c0006.json',
#  'batch_outputs/path_all_0158_f0000_r0017_c0006.png',
#  'batch_outputs/path_all_0159_f0000_r0019_c0005.json',
#  'batch_outputs/path_all_0159_f0000_r0019_c0005.png',
#  'batch_outputs/path_all_0160_f0000_r0018_c0003.json',
#  'batch_outputs/path_all_0160_f0000_r0018_c0003.png',
#  'batch_outputs/path_all_0161_f0000_r0020_c0001.json',
#  'batch_outputs/path_all_0161_f0000_r0020_c0001.png',
#  'batch_outputs/path_all_0162_f0000_r0022_c0000.json',
#  'batch_outputs/path_all_0162_f0000_r0022_c0000.png',
#  'batch_outputs/path_all_0163_f0000_r0024_c0001.json',
#  'batch_outputs/path_all_0163_f0000_r0024_c0001.png',
#  'batch_outputs/path_all_0164_f0000_r0025_c0003.json',
#  'batch_outputs/path_all_0164_f0000_r0025_c0003.png',
#  'batch_outputs/path_all_0165_f0000_r0023_c0005.json',
#  'batch_outputs/path_all_0165_f0000_r0023_c0005.png',
#  'batch_outputs/path_all_0166_f0000_r0025_c0006.json',
#  'batch_outputs/path_all_0166_f0000_r0025_c0006.png',
#  'batch_outputs/path_all_0167_f0000_r0027_c0005.json',
#  'batch_outputs/path_all_0167_f0000_r0027_c0005.png',
#  'batch_outputs/path_all_0168_f0000_r0028_c0007.json',
#  'batch_outputs/path_all_0168_f0000_r0028_c0007.png',
#  'batch_outputs/path_all_0169_f0000_r0030_c0008.json',
#  'batch_outputs/path_all_0169_f0000_r0030_c0008.png',
#  'batch_outputs/path_all_0170_f0000_r0032_c0009.json',
#  'batch_outputs/path_all_0170_f0000_r0032_c0009.png',
#  'batch_outputs/path_all_0171_f0000_r0034_c0008.json',
#  'batch_outputs/path_all_0171_f0000_r0034_c0008.png',
#  'batch_outputs/path_all_0172_f0000_r0035_c0010.json',
#  'batch_outputs/path_all_0172_f0000_r0035_c0010.png',
#  'batch_outputs/path_all_0173_f0000_r0033_c0012.json',
#  'batch_outputs/path_all_0173_f0000_r0033_c0012.png',
#  'batch_outputs/path_all_0174_f0000_r0031_c0011.json',
#  'batch_outputs/path_all_0174_f0000_r0031_c0011.png',
#  'batch_outputs/path_all_0175_f0000_r0030_c0013.json',
#  'batch_outputs/path_all_0175_f0000_r0030_c0013.png',
#  'batch_outputs/path_all_0176_f0000_r0031_c0015.json',
#  'batch_outputs/path_all_0176_f0000_r0031_c0015.png',
#  'batch_outputs/path_all_0177_f0000_r0033_c0017.json',
#  'batch_outputs/path_all_0177_f0000_r0033_c0017.png',
#  'batch_outputs/path_all_0178_f0000_r0031_c0018.json',
#  'batch_outputs/path_all_0178_f0000_r0031_c0018.png',
#  'batch_outputs/path_all_0179_f0000_r0030_c0020.json',
#  'batch_outputs/path_all_0179_f0000_r0030_c0020.png',
#  'batch_outputs/path_all_0180_f0000_r0031_c0022.json',
#  'batch_outputs/path_all_0180_f0000_r0031_c0022.png',
#  'batch_outputs/path_all_0181_f0000_r0033_c0020.json',
#  'batch_outputs/path_all_0181_f0000_r0033_c0020.png',
#  'batch_outputs/path_all_0182_f0000_r0035_c0019.json',
#  'batch_outputs/path_all_0182_f0000_r0035_c0019.png',
#  'batch_outputs/path_all_0183_f0000_r0035_c0023.json',
#  'batch_outputs/path_all_0183_f0000_r0035_c0023.png',
#  'batch_outputs/path_all_0184_f0000_r0033_c0025.json',
#  'batch_outputs/path_all_0184_f0000_r0033_c0025.png',
#  'batch_outputs/path_all_0185_f0000_r0034_c0027.json',
#  'batch_outputs/path_all_0185_f0000_r0034_c0027.png',
#  'batch_outputs/path_all_0186_f0000_r0029_c0030.json',
#  'batch_outputs/path_all_0186_f0000_r0029_c0030.png',
#  'batch_outputs/path_all_0187_f0000_r0027_c0031.json',
#  'batch_outputs/path_all_0187_f0000_r0027_c0031.png',
#  'batch_outputs/path_all_0188_f0000_r0026_c0033.json',
#  'batch_outputs/path_all_0188_f0000_r0026_c0033.png',
#  'batch_outputs/path_all_0189_f0000_r0027_c0035.json',
#  'batch_outputs/path_all_0189_f0000_r0027_c0035.png',
#  'batch_outputs/path_all_0190_f0000_r0024_c0035.json',
#  'batch_outputs/path_all_0190_f0000_r0024_c0035.png',
#  'batch_outputs/path_all_0191_f0000_r0021_c0030.json',
#  'batch_outputs/path_all_0191_f0000_r0021_c0030.png',
#  'batch_outputs/path_all_0192_f0000_r0019_c0031.json',
#  'batch_outputs/path_all_0192_f0000_r0019_c0031.png',
#  'batch_outputs/path_all_0193_f0000_r0018_c0028.json',
#  'batch_outputs/path_all_0193_f0000_r0018_c0028.png',
#  'batch_outputs/path_all_0194_f0000_r0020_c0027.json',
#  'batch_outputs/path_all_0194_f0000_r0020_c0027.png',
#  'batch_outputs/path_all_0195_f0000_r0021_c0025.json',
#  'batch_outputs/path_all_0195_f0000_r0021_c0025.png',
#  'batch_outputs/path_all_0196_f0000_r0016_c0026.json',
#  'batch_outputs/path_all_0196_f0000_r0016_c0026.png',
#  'batch_outputs/path_all_0197_f0000_r0013_c0026.json',
#  'batch_outputs/path_all_0197_f0000_r0013_c0026.png',
#  'batch_outputs/path_all_0198_f0000_r0011_c0028.json',
#  'batch_outputs/path_all_0198_f0000_r0011_c0028.png',
#  'batch_outputs/path_all_0199_f0000_r0009_c0026.json',
#  'batch_outputs/path_all_0199_f0000_r0009_c0026.png',
#  'batch_outputs/path_all_0200_f0000_r0011_c0024.json',
#  'batch_outputs/path_all_0200_f0000_r0011_c0024.png',
#  'batch_outputs/path_all_0201_f0000_r0008_c0023.json',
#  'batch_outputs/path_all_0201_f0000_r0008_c0023.png',
#  'batch_outputs/path_all_0202_f0000_r0006_c0024.json',
#  'batch_outputs/path_all_0202_f0000_r0006_c0024.png',
#  'batch_outputs/path_all_0203_f0000_r0004_c0026.json',
#  'batch_outputs/path_all_0203_f0000_r0004_c0026.png',
#  'batch_outputs/path_all_0204_f0000_r0006_c0027.json',
#  'batch_outputs/path_all_0204_f0000_r0006_c0027.png',
#  'batch_outputs/path_all_0205_f0000_r0004_c0029.json',
#  'batch_outputs/path_all_0205_f0000_r0004_c0029.png',
#  'batch_outputs/path_all_0206_f0000_r0006_c0021.json',
#  'batch_outputs/path_all_0206_f0000_r0006_c0021.png',
#  'batch_outputs/path_all_0207_f0000_r0008_c0019.json',
#  'batch_outputs/path_all_0207_f0000_r0008_c0019.png',
#  'batch_outputs/path_all_0208_f0000_r0010_c0021.json',
#  'batch_outputs/path_all_0208_f0000_r0010_c0021.png',
#  'batch_outputs/path_all_0209_f0000_r0012_c0018.json',
#  'batch_outputs/path_all_0209_f0000_r0012_c0018.png',
#  'batch_outputs/path_all_0210_f0000_r0013_c0016.json',
#  'batch_outputs/path_all_0210_f0000_r0013_c0016.png',
#  'batch_outputs/path_all_0211_f0000_r0011_c0014.json',
#  'batch_outputs/path_all_0211_f0000_r0011_c0014.png',
#  'batch_outputs/path_all_0212_f0000_r0010_c0016.json',
#  'batch_outputs/path_all_0212_f0000_r0010_c0016.png',
#  'batch_outputs/path_all_0213_f0000_r0005_c0011.json',
#  'batch_outputs/path_all_0213_f0000_r0005_c0011.png',
#  'batch_outputs/path_all_0214_f0000_r0003_c0009.json',
#  'batch_outputs/path_all_0214_f0000_r0003_c0009.png',
#  'batch_outputs/path_all_0215_f0000_r0002_c0011.json',
#  'batch_outputs/path_all_0215_f0000_r0002_c0011.png',
#  'batch_outputs/path_all_0216_f0000_r0000_c0013.json',
#  'batch_outputs/path_all_0216_f0000_r0000_c0013.png',
#  'batch_outputs/path_all_0217_f0000_r0003_c0014.json',
#  'batch_outputs/path_all_0217_f0000_r0003_c0014.png',
#  'batch_outputs/path_all_0218_f0000_r0000_c0009.json',
#  'batch_outputs/path_all_0218_f0000_r0000_c0009.png',
#  'batch_outputs/path_all_0219_f0000_r0001_c0007.json',
#  'batch_outputs/path_all_0219_f0000_r0001_c0007.png',
#  'batch_outputs/path_all_0220_f0000_r0003_c0006.json',
#  'batch_outputs/path_all_0220_f0000_r0003_c0006.png',
#  'batch_outputs/path_all_0221_f0000_r0002_c0004.json',
#  'batch_outputs/path_all_0221_f0000_r0002_c0004.png',
#  'batch_outputs/path_all_0222_f0000_r0000_c0005.json',
#  'batch_outputs/path_all_0222_f0000_r0000_c0005.png',
#  'batch_outputs/path_all_0223_f0000_r0000_c0002.json',
#  'batch_outputs/path_all_0223_f0000_r0000_c0002.png',
#  'batch_outputs/path_all_0224_f0000_r0002_c0001.json',
#  'batch_outputs/path_all_0224_f0000_r0002_c0001.png',
#  'batch_outputs/path_all_0225_f0000_r0005_c0001.json',
#  'batch_outputs/path_all_0225_f0000_r0005_c0001.png',
#  'batch_outputs/path_all_0226_f0000_r0007_c0000.json',
#  'batch_outputs/path_all_0226_f0000_r0007_c0000.png',
#  'batch_outputs/path_all_0227_f0000_r0007_c0003.json',
#  'batch_outputs/path_all_0227_f0000_r0007_c0003.png',
#  'batch_outputs/path_all_0228_f0000_r0005_c0004.json',
#  'batch_outputs/path_all_0228_f0000_r0005_c0004.png',
#  'batch_outputs/path_all_0229_f0000_r0005_c0007.json',
#  'batch_outputs/path_all_0229_f0000_r0005_c0007.png',
#  'batch_outputs/path_all_0230_f0000_r0008_c0006.json',
#  'batch_outputs/path_all_0230_f0000_r0008_c0006.png',
#  'batch_outputs/path_all_0231_f0000_r0010_c0004.json',
#  'batch_outputs/path_all_0231_f0000_r0010_c0004.png',
#  'batch_outputs/path_all_0232_f0000_r0012_c0002.json',
#  'batch_outputs/path_all_0232_f0000_r0012_c0002.png',
#  'batch_outputs/path_all_0233_f0000_r0013_c0000.json',
#  'batch_outputs/path_all_0233_f0000_r0013_c0000.png',
#  'batch_outputs/path_all_0234_f0000_r0010_c0001.json',
#  'batch_outputs/path_all_0234_f0000_r0010_c0001.png',
#  'batch_outputs/path_all_0235_f0000_r0015_c0003.json',
#  'batch_outputs/path_all_0235_f0000_r0015_c0003.png',
#  'batch_outputs/path_all_0236_f0000_r0016_c0001.json',
#  'batch_outputs/path_all_0236_f0000_r0016_c0001.png',
#  'batch_outputs/path_all_0237_f0000_r0018_c0000.json',
#  'batch_outputs/path_all_0237_f0000_r0018_c0000.png',
#  'batch_outputs/path_all_0238_f0000_r0022_c0003.json',
#  'batch_outputs/path_all_0238_f0000_r0022_c0003.png',
#  'batch_outputs/path_all_0239_f0000_r0027_c0000.json',
#  'batch_outputs/path_all_0239_f0000_r0027_c0000.png',
#  'batch_outputs/path_all_0240_f0000_r0028_c0002.json',
#  'batch_outputs/path_all_0240_f0000_r0028_c0002.png',
#  'batch_outputs/path_all_0241_f0000_r0030_c0000.json',
#  'batch_outputs/path_all_0241_f0000_r0030_c0000.png',
#  'batch_outputs/path_all_0242_f0000_r0031_c0002.json',
#  'batch_outputs/path_all_0242_f0000_r0031_c0002.png',
#  'batch_outputs/path_all_0243_f0000_r0033_c0003.json',
#  'batch_outputs/path_all_0243_f0000_r0033_c0003.png',
#  'batch_outputs/path_all_0244_f0000_r0035_c0002.json',
#  'batch_outputs/path_all_0244_f0000_r0035_c0002.png',
#  'batch_outputs/path_all_0245_f0000_r0033_c0000.json',
#  'batch_outputs/path_all_0245_f0000_r0033_c0000.png',
#  'batch_outputs/path_all_0246_f0000_r0035_c0005.json',
#  'batch_outputs/path_all_0246_f0000_r0035_c0005.png',
#  'batch_outputs/path_all_0247_f0000_r0033_c0006.json',
#  'batch_outputs/path_all_0247_f0000_r0033_c0006.png',
#  'batch_outputs/path_all_0248_f0000_r0030_c0005.json',
#  'batch_outputs/path_all_0248_f0000_r0030_c0005.png',
#  'batch_outputs/path_all_0249_f0000_r0026_c0008.json',
#  'batch_outputs/path_all_0249_f0000_r0026_c0008.png',
#  'batch_outputs/path_all_0250_f0000_r0028_c0010.json',
#  'batch_outputs/path_all_0250_f0000_r0028_c0010.png',
#  'batch_outputs/path_all_0251_f0000_r0026_c0011.json',
#  'batch_outputs/path_all_0251_f0000_r0026_c0011.png',
#  'batch_outputs/path_all_0252_f0000_r0028_c0014.json',
#  'batch_outputs/path_all_0252_f0000_r0028_c0014.png',
#  'batch_outputs/path_all_0253_f0000_r0026_c0015.json',
#  'batch_outputs/path_all_0253_f0000_r0026_c0015.png',
#  'batch_outputs/path_all_0254_f0000_r0028_c0017.json',
#  'batch_outputs/path_all_0254_f0000_r0028_c0017.png',
#  'batch_outputs/path_all_0255_f0000_r0035_c0015.json',
#  'batch_outputs/path_all_0255_f0000_r0035_c0015.png',
#  'batch_outputs/path_all_0256_f0000_r0028_c0027.json',
#  'batch_outputs/path_all_0256_f0000_r0028_c0027.png',
#  'batch_outputs/path_all_0257_f0000_r0026_c0028.json',
#  'batch_outputs/path_all_0257_f0000_r0026_c0028.png',
#  'batch_outputs/path_all_0258_f0000_r0015_c0008.json',
#  'batch_outputs/path_all_0258_f0000_r0015_c0008.png',
#  'batch_outputs/path_all_0259_f0000_r0013_c0006.json',
#  'batch_outputs/path_all_0259_f0000_r0013_c0006.png',
#  'synthetic_4dstem.npy']
