# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1

# %% [markdown]
# # IO.folder
#
# Read all files in a folder as a stack with `IO.folder(path)`. Supports `file_type` filter and `recursive` flag.

# %%
from quantem.widget import IO, Show3D

# %% [markdown]
# ## TIFF folder

# %%
result = IO.folder("/Users/macbook/data/20251216_Korea_Sample_C1/", file_type="tif")
print(result)
Show3D(result, title="Korean Sample Virtual Images")

# %% [markdown]
# ## EMD folder

# %%
result = IO.folder("/Users/macbook/data/20251209_KoreanSample/D1_STEM_Karen/", file_type="emd")
print(result)
Show3D(result, title="Korean D1 STEM HAADF Series")

# %% [markdown]
# ## DM3 folder

# %%
result = IO.folder(
    "/Users/macbook/data/20251209_KoreanSample/C1_TEM_Bob/Bob_Lee_Sangjoon/",
    file_type="dm3",
)
print(result)
Show3D(result, title="Co3O4 TEM Series")

# %% [markdown]
# ## Recursive folder

# %%
result = IO.folder(
    "/Users/macbook/data/20251209_KoreanSample/C1_TEM_Bob/Bob_Lee_Sangjoon/",
    file_type="dm3",
    recursive=True,
)
print(result)
